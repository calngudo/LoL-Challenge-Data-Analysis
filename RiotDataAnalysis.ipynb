# %%
import os
from dotenv import load_dotenv
load_dotenv()
print(os.environ.get('riot_api_key'))
API_KEY = os.getenv("API_KEY")
# Out:
# None

# %%
import pygsheets
service_account = pygsheets.authorize(service_file='path/to/your/service_account_credentials.json')
