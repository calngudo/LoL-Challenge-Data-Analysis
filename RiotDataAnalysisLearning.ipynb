# %%
pip install pandas numpy pygsheets
# Out:
# Requirement already satisfied: pandas in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (2.3.5)
# Requirement already satisfied: pygsheets in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: google-api-python-client>=2.50.0 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from pygsheets) (2.187.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.1 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from pygsheets) (1.2.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-python-client>=2.50.0->pygsheets) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-python-client>=2.50.0->pygsheets) (2.41.1)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-python-client>=2.50.0->pygsheets) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-python-client>=2.50.0->pygsheets) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-python-client>=2.50.0->pygsheets) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (6.33.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=2.50.0->pygsheets) (6.2.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=2.50.0->pygsheets) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=2.50.0->pygsheets) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=2.50.0->pygsheets) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=2.50.0->pygsheets) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from google-auth-oauthlib>=0.7.1->pygsheets) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\cal\desktop\riot challenge\lol-challenge-data-analysis\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.1->pygsheets) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Playing with Google Sheets API
import pygsheets
service_account = pygsheets.authorize(service_file='JSONs\\sacred-machine-481117-v7-c1c1ee2e05af.json')

sheet = service_account.open_by_url("https://docs.google.com/spreadsheets/d/1am8ie_kqq52wcbJ1pnpVkwVYQWKep1Wxsp_UZe90w3c/edit?usp=sharing")

test = sheet.worksheet_by_title('Sheet1')
print(test.get_as_df())
# Out:
#     Random_numbers
# 0               99
# 1               89
# 2                1
# 3               35
# 4                9
# 5                6
# 6               24
# 7               75
# 8               70
# 9               43
# 10              57
# 11              58
# 12              68
# 13              55
# 14              93
# 15              70
# 16              66

# %%
import os, requests
from dotenv import load_dotenv
load_dotenv()

RIOT_API_KEY = os.environ.get('RIOT_API_KEY')

def get_puuid(gameName, tagLine):
    link = f'https://americas.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{gameName}/{tagLine}?api_key={RIOT_API_KEY}'
    response = requests.get(link)
    if response.status_code == 200:
        return response.json()['puuid']
    else:
        print(response.status_code, response.text)

# %%
get_puuid('Pyanioux', 'Data')
# Out:
# 200 {"puuid":"_cXtlPyThOESVsXDyoljmo9Nzps-3tVZ_eL2KaeqfnDX_bNiLDvQolScS6sSdnqGXhFYDU1odyMQJA","gameName":"Pyanioux","tagLine":"Data"}
# '_cXtlPyThOESVsXDyoljmo9Nzps-3tVZ_eL2KaeqfnDX_bNiLDvQolScS6sSdnqGXhFYDU1odyMQJA'

# %%
#Define challenge start and end dates in UTC
datestart = '1756425600' #August 29 2025
dateend = '1764633600' #December 02 2025

#Participating users
users = ['Bendyboy#NA1',
'frak#NA1',
'Pyanioux#Data',
'Buttbeard224#NA1',
'StoveOnTheGo#Stove',
'applejack#cats',
'MariaOyonashi#NA1',
'trev#2829',
'e4e6d4d5#echec',
'sirNovaFire#NA1',
'ProtectAbichan#NA1',
'medealilyisbae#NA1',
'Shihouin#Yoru',
'kazuha#rsrf']

queuetype = '440' #Ranked Flex

#Get PUUIDs for all users
user_puuids = {}
for user in users:
    game_name, tag_line = user.split('#')
    puuid = get_puuid(game_name, tag_line)
    if puuid:
        user_puuids[user] = puuid

print(user_puuids)
# Out:
# 200 {"puuid":"wbBqqaq6TrD6VymohefN3I-BE2t9ylArAwggDD3eGWa_rruAeuIgxF5-CnPVRH3w2Ne5X3OI3T_gmw","gameName":"Bendyboy","tagLine":"NA1"}
# 200 {"puuid":"WdAciwLJfcatV_55zvHxrLGkpoTqIWTH45zUnpD-6ZBdxS2N5uEJv7RD6D0UANWKqElnHdswCSH9JA","gameName":"frak","tagLine":"NA1"}
# 200 {"puuid":"_cXtlPyThOESVsXDyoljmo9Nzps-3tVZ_eL2KaeqfnDX_bNiLDvQolScS6sSdnqGXhFYDU1odyMQJA","gameName":"Pyanioux","tagLine":"Data"}
# 200 {"puuid":"BMG6KUOIrJVIS8ohiAYqu1L_DC4JEbasRYqeAJRaubNerIVYu-keWz2LExyMe1gKZTcq9pLidYZqfw","gameName":"Buttbeard224","tagLine":"NA1"}
# 200 {"puuid":"WiQKNYHuI269YB4jlpE9xAGN8lJWAkob-Y0AhzS9WvSxUttNFFsx-YkDHxFX_fjrWOXQPwVWmC_3Mg","gameName":"StoveOnTheGo","tagLine":"Stove"}
# 200 {"puuid":"fprMFB8JXKCupdSMzYOu4Y3RBUdRvKFiNzJ762-qUB45zESLDUVvVaShFzbShrbmlGuE48QhUKWVqQ","gameName":"applejack","tagLine":"cats"}
# 200 {"puuid":"9gV5rJ6mlzUhof0uX4QLfXYWnBhwuFPJd0Ac2J6Xg_0uMOSXY_ZBgTlxwa5Ps307dZ6iev222C3p0g","gameName":"MariaOyonashi","tagLine":"NA1"}
# 200 {"puuid":"4BtRbQUg0ZrKEceNVAtZ5CPhTA6pYqln2GP7qsuX3hUBbNF2vsHFAQMiazZfqZ0g8z7T7Of2aWWznA","gameName":"trev","tagLine":"2829"}
# 200 {"puuid":"rXPR9-t2T8TQbgcUAdY3QPQvBqhDFr-Wj681gnML6f-2tCmimBCoUTRdQIlptb3uMqZjaiM2vnHp2g","gameName":"e4e6d4d5","tagLine":"echec"}
# 200 {"puuid":"re8QTQN1mpC9O5RaRXKz_sDnUUE9vdDVyXLkVjOQGSrTCExpLMsit3RZWCTvz1-xVN6yoPRDi-vj9w","gameName":"sirNovafire","tagLine":"NA1"}
# 200 {"puuid":"nvMQRG4uzPm8qnaxqP379mZ2Hjxw-r8w7aZdDSEuUMITaRvexocPMYNFzWV_lOygQCn7I1Mbr-zngQ","gameName":"ProtectAbichan","tagLine":"NA1"}
# 200 {"puuid":"sItfJdrJYdt9h15iyZ6ewMmTvw5dLmVHBjPcoU0ouj8I50rWNAU7bziFPEAGU7raozvTPPmPBgisog","gameName":"kazuha","tagLine":"rsrf"}
# {'Bendyboy#NA1': 'wbBqqaq6TrD6VymohefN3I-BE2t9ylArAwggDD3eGWa_rruAeuIgxF5-CnPVRH3w2Ne5X3OI3T_gmw', 'frak#NA1': 'WdAciwLJfcatV_55zvHxrLGkpoTqIWTH45zUnpD-6ZBdxS2N5uEJv7RD6D0UANWKqElnHdswCSH9JA', 'Pyanioux#Data': '_cXtlPyThOESVsXDyoljmo9Nzps-3tVZ_eL2KaeqfnDX_bNiLDvQolScS6sSdnqGXhFYDU1odyMQJA', 'Buttbeard224#NA1': 'BMG6KUOIrJVIS8ohiAYqu1L_DC4JEbasRYqeAJRaubNerIVYu-keWz2LExyMe1gKZTcq9pLidYZqfw', 'StoveOnTheGo#Stove': 'WiQKNYHuI269YB4jlpE9xAGN8lJWAkob-Y0AhzS9WvSxUttNFFsx-YkDHxFX_fjrWOXQPwVWmC_3Mg', 'Applejack#cats': 'fprMFB8JXKCupdSMzYOu4Y3RBUdRvKFiNzJ762-qUB45zESLDUVvVaShFzbShrbmlGuE48QhUKWVqQ', 'MariaOyonashi#NA1': '9gV5rJ6mlzUhof0uX4QLfXYWnBhwuFPJd0Ac2J6Xg_0uMOSXY_ZBgTlxwa5Ps307dZ6iev222C3p0g', 'trev#2829': '4BtRbQUg0ZrKEceNVAtZ5CPhTA6pYqln2GP7qsuX3hUBbNF2vsHFAQMiazZfqZ0g8z7T7Of2aWWznA', 'e4e6d4d5#echec': 'rXPR9-t2T8TQbgcUAdY3QPQvBqhDFr-Wj681gnML6f-2tCmimBCoUTRdQIlptb3uMqZjaiM2vnHp2g', 'sirNovaFire#NA1': 're8QTQN1mpC9O5RaRXKz_sDnUUE9vdDVyXLkVjOQGSrTCExpLMsit3RZWCTvz1-xVN6yoPRDi-vj9w', 'ProtectAbichan#NA1': 'nvMQRG4uzPm8qnaxqP379mZ2Hjxw-r8w7aZdDSEuUMITaRvexocPMYNFzWV_lOygQCn7I1Mbr-zngQ', 'kazuha#rsrf': 'sItfJdrJYdt9h15iyZ6ewMmTvw5dLmVHBjPcoU0ouj8I50rWNAU7bziFPEAGU7raozvTPPmPBgisog'}

# %%
def get_matchhistory(puuid, count):
    link = f'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?startTime={datestart}&endTime={dateend}&queue={queuetype}&type=ranked&start=0&count={count}&api_key={RIOT_API_KEY}'
    response = requests.get(link)
    if response.status_code == 200:
        return response.json()
    else:
        print(response.status_code, response.text)
get_matchhistory(user_puuids['Pyanioux#Data'], count=5)
# Out:
# ['NA1_5423324194',
#  'NA1_5423298506',
#  'NA1_5423270896',
#  'NA1_5423252132',
#  'NA1_5423209815']

# %%
def get_match_details(match_id):
    link = f'https://americas.api.riotgames.com/lol/match/v5/matches/{match_id}?api_key={RIOT_API_KEY}'
    response = requests.get(link)
    if response.status_code == 200:
        return response.json()
    else:
        print(response.status_code, response.text)

match_data = get_match_details('NA1_5423324194')
print(match_data)
# Out:
# {'metadata': {'dataVersion': '2', 'matchId': 'NA1_5423324194', 'participants': ['XYINcRctXdqGbXitUzFHluXQcZtfAWBMkenJaFqlvg8GhwwcmFFsMmiNvc4KBE4bVdEEpRHyhVEpCA', 'xQ3w-WcBzwfwB8lsFREI13Uy4LG7v0fFI0WznmhTBzU3TlVYTQOb_DqbfJpgldCTR7-eE1b-waXqoA', 'Qo1FSTfPz0e-dvftXc6zMYBtRzu8RSDjbqAdxd7tnR1jD760eEx6JhsF6kAtwmY9I3yCZcCwN7Eu3A', '2NZR6TC4HKWOCFfQKnbHPGXKUhAxEweqrkeTl3ERUXUUblLlQ4LvWqHQsfLW6C14krFHLvJzVAsijQ', 'jHM9xcog5lK7yODTOENhno6iJcjdLT_d_WqEhFhKXioQPLaNtl7iWBsDU-LueKeG08EKpoYRKuvt8w', 'wbBqqaq6TrD6VymohefN3I-BE2t9ylArAwggDD3eGWa_rruAeuIgxF5-CnPVRH3w2Ne5X3OI3T_gmw', 'WdAciwLJfcatV_55zvHxrLGkpoTqIWTH45zUnpD-6ZBdxS2N5uEJv7RD6D0UANWKqElnHdswCSH9JA', '4BtRbQUg0ZrKEceNVAtZ5CPhTA6pYqln2GP7qsuX3hUBbNF2vsHFAQMiazZfqZ0g8z7T7Of2aWWznA', 'WiQKNYHuI269YB4jlpE9xAGN8lJWAkob-Y0AhzS9WvSxUttNFFsx-YkDHxFX_fjrWOXQPwVWmC_3Mg', '_cXtlPyThOESVsXDyoljmo9Nzps-3tVZ_eL2KaeqfnDX_bNiLDvQolScS6sSdnqGXhFYDU1odyMQJA']}, 'info': {'endOfGameResult': 'GameComplete', 'gameCreation': 1764313055414, 'gameDuration': 1658, 'gameEndTimestamp': 1764314738133, 'gameId': 5423324194, 'gameMode': 'CLASSIC', 'gameName': 'teambuilder-match-5423324194', 'gameStartTimestamp': 1764313079517, 'gameType': 'MATCHED_GAME', 'gameVersion': '15.23.728.3286', 'mapId': 11, 'participants': [{'PlayerScore0': 0, 'PlayerScore1': 0, 'PlayerScore10': 0, 'PlayerScore11': 0, 'PlayerScore2': 0, 'PlayerScore3': 0, 'PlayerScore4': 0, 'PlayerScore5': 0, 'PlayerScore6': 0, 'PlayerScore7': 0, 'PlayerScore8': 0, 'PlayerScore9': 0, 'allInPings': 0, 'assistMePings': 1, 'assists': 4, 'baronKills': 0, 'basicPings': 0, 'challenges': {'12AssistStreakCount': 0, 'HealFromMapSources': 0, 'InfernalScalePickup': 0, 'SWARM_DefeatAatrox': 0, 'SWARM_DefeatBriar': 0, 'SWARM_DefeatMiniBosses': 0, 'SWARM_EvolveWeapon': 0, 'SWARM_Have3Passives': 0, 'SWARM_KillEnemy': 0, 'SWARM_PickupGold': 0, 'SWARM_ReachLevel50': 0, 'SWARM_Survive15Min': 0, 'SWARM_WinWith5EvolvedWeapons': 0, 'abilityUses': 252, 'acesBefore15Minutes': 0, 'alliedJungleMonsterKills': 0, 'baronTakedowns': 0, 'blastConeOppositeOpponentCount': 0, 'bountyGold': 0, 'buffsStolen': 0, 'completeSupportQuestInTime': 0, 'controlWardsPlaced': 0, 'damagePerMinute': 474.2014061169937, 'damageTakenOnTeamPercentage': 0.20874390916130972, 'dancedWithRiftHerald': 0, 'deathsByEnemyChamps': 9, 'dodgeSkillShotsSmallWindow': 0, 'doubleAces': 0, 'dragonTakedowns': 0, 'earlyLaningPhaseGoldExpAdvantage': 0, 'effectiveHealAndShielding': 0, 'elderDragonKillsWithOpposingSoul': 0, 'elderDragonMultikills': 0, 'enemyChampionImmobilizations': 51, 'enemyJungleMonsterKills': 0, 'epicMonsterKillsNearEnemyJungler': 0, 'epicMonsterKillsWithin30SecondsOfSpawn': 0, 'epicMonsterSteals': 0, 'epicMonsterStolenWithoutSmite': 0, 'firstTurretKilled': 0, 'fistBumpParticipation': 0, 'flawlessAces': 0, 'fullTeamTakedown': 2, 'gameLength': 1658.9874049470002, 'getTakedownsInAllLanesEarlyJungleAsLaner': 0, 'goldPerMinute': 284.3861300005303, 'hadOpenNexus': 0, 'immobilizeAndKillWithAlly': 4, 'initialBuffCount': 0, 'initialCrabCount': 0, 'jungleCsBefore10Minutes': 0, 'junglerTakedownsNearDamagedEpicMonster': 0, 'kTurretsDestroyedBeforePlatesFall': 0, 'kda': 0.6666666666666666, 'killAfterHiddenWithAlly': 0, 'killParticipation': 0.4, 'killedChampTookFullTeamDamageSurvived': 0, 'killingSprees': 0, 'killsNearEnemyTurret': 1, 'killsOnOtherLanesEarlyJungleAsLaner': 0, 'killsOnRecentlyHealedByAramPack': 0, 'killsUnderOwnTurret': 1, 'killsWithHelpFromEpicMonster': 0, 'knockEnemyIntoTeamAndKill': 5, 'landSkillShotsEarlyGame': 5, 'laneMinionsFirst10Minutes': 57, 'laningPhaseGoldExpAdvantage': 0, 'legendaryCount': 0, 'legendaryItemUsed': [6697, 6610], 'lostAnInhibitor': 0, 'maxCsAdvantageOnLaneOpponent': 15, 'maxKillDeficit': 0, 'maxLevelLeadLaneOpponent': 1, 'mejaisFullStackInTime': 0, 'moreEnemyJungleThanOpponent': 0, 'multiKillOneSpell': 0, 'multiTurretRiftHeraldCount': 0, 'multikills': 0, 'multikillsAfterAggressiveFlash': 0, 'outerTurretExecutesBefore10Minutes': 0, 'outnumberedKills': 0, 'outnumberedNexusKill ...

# %%
def store_match_data(match_data, users):
    participants = match_data['info']['participants']
    users_match_data = {}
    for participant in participants:
            participant_id = f"{participant['riotIdGameName']}#{participant['riotIdTagline']}"
            if participant_id in users:
                users_match_data[participant_id] = {
                    'participantId': participant['participantId'],
                    'championName': participant['championName'],
                    'kills': participant['kills'],
                    'deaths': participant['deaths'],
                    'assists': participant['assists'],
                    'win': participant['win'],
                    'teamId': participant['teamId'],
                }
    for user_id, data in users_match_data.items():
            print(f"\n{user_id}:")
            print(f"  Participant ID: {data['participantId']}")
            print(f"  Champion: {data['championName']}")
            print(f"  KDA: {data['kills']}/{data['deaths']}/{data['assists']}")
            print(f"  Win: {data['win']}")
            print(f"  Team: {data['teamId']}")
store_match_data(match_data, users)
# Out:
# Bendyboy#NA1:
#   Participant ID: 6
#   Champion: Chogath
#   KDA: 12/2/5
#   Win: True
#   Team: 200
#
# frak#NA1:
#   Participant ID: 7
#   Champion: Ivern
#   KDA: 7/0/19
#   Win: True
#   Team: 200
#
# trev#2829:
#   Participant ID: 8
#   Champion: Zaahen
#   KDA: 4/5/8
#   Win: True
#   Team: 200
#
# StoveOnTheGo#Stove:
#   Participant ID: 9
#   Champion: Leblanc
#   KDA: 8/6/12
#   Win: True
#   Team: 200
#
# Pyanioux#Data:
#   Participant ID: 10
#   Champion: Renekton
#   KDA: 6/2/6
#   Win: True
#   Team: 200
